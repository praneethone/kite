# %%
df = spark.createDataFrame([
    (1, 'January'),
    (2, 'January'),
    (3, 'January'),
    (4, 'January'),
    (5, 'February'),
    (6, 'February'),
    (7, 'February'),
    (8, 'February')
], ['week', 'month'])
display(df)

# %%
df=spark.createDataFrame([(1,2),(3,4),(5,6)],['c1','c2'])
df.show()

# %% [markdown]
# creating a spark dataframe

# %%
df=df.spark.createdtaaframe
